# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from collections import Counter

# %%
# --- Device ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
from google.colab import drive
import zipfile
import os


drive.mount('/content/drive')

zip_path = '/content/drive/MyDrive/anime_dataset.zip'


extract_path = '/content/anime_dataset'


with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)


print(os.listdir(extract_path))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['train', 'test']

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from PIL import Image

# %%
def pil_loader_rgb(path: str):
    with open(path, 'rb') as f:
        img = Image.open(f)
        return img.convert("RGB")  # convert palette/transparency immediately

train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
# --- Datasets ---
train_dataset = datasets.ImageFolder("/content/anime_dataset/train", transform=train_transforms, loader = pil_loader_rgb)
test_dataset = datasets.ImageFolder("/content/anime_dataset/test", transform=test_transforms, loader = pil_loader_rgb)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
print("Number of classes:", len(train_dataset.classes))

# Count number of images per class
labels = [label for _, label in train_dataset.samples]
class_counts = Counter(labels)
Total = 0
for _, count in class_counts.items():
    Total+= count
print("Total images:", Total)
# Out:
# Number of classes: 493
# Total images: 8140

# %%
temp = train_dataset.classes

# %%
import json

print(json.dumps(temp, ensure_ascii=False))
# Out:
# ["20th Century Boys", "3gatsu no Lion", "5toubun no Hanayome", "86", "91 Days", "Accel World", "Acchi Kocchi", "Ajin Part 2 OVA", "AkaKill Gekijou", "Akagami no Shirayukihime", "Akame ga Kill", "Akatsuki no Yona", "Akira", "Aku no Hana", "AldnoahZero", "Amagi Brilliant Park", "Angel Beats", "Angel Beats Specials", "Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai", "Another", "Ansatsu Kyoushitsu", "Ao Haru Ride", "Ao no Exorcist", "Ao no Hako", "Aria the Animation", "Arifureta Shokugyou de Sekai Saikyou", "Ashita no Joe", "Asobi Asobase", "Ayakashi", "Azumanga Daiou The Animation", "Baccano", "Bakemonogatari", "Bakuman", "Banana Fish", "Barakamon", "Beastars", "Beelzebub", "Berserk", "Bishoujo Senshi Sailor Moon", "Black Cat TV", "Black Clover", "Black Lagoon", "Black Lagoon Omake", "BlackRock Shooter OVA", "Bleach", "Bleach Movie 2", "Blood", "Blood Lad", "Blue Lock", "Blue Period", "Bocchi the Rock", "Boku dake ga Inai Machi", "Boku no Hero Academia", "Boku no Hero Academia 2nd Season", "Boku no Hero Academia 3rd Season", "Boku no Hero Academia 4th Season", "Boku no Kokoro no Yabai Yatsu", "Boku wa Tomodachi ga Sukunai", "Bokura no Live Kimi to no Life", "Bokutachi wa Benkyou ga Dekinai", "Boruto", "Bungou Stray Dogs", "Bungou Stray Dogs 2nd Season", "Cardcaptor Sakura", "Carnival Phantasm EX Season", "Chainsaw Man", "Chainsaw Man Movie", "Charlotte", "Chihayafuru", "Chobits", "Chuunibyou demo Koi ga Shitai", "Citrus", "Clannad", "Clannad Movie", "Claymore", "Code Geass", "Cowboy Bebop", "Cyberpunk", "DGrayman", "Dandadan", "Danganronpa", "Danganronpa 3", "Danshi Koukousei no Nichijou", "Darker than Black", "Darling in the FranXX", "Date A Live", "Date A Live II", "Deadman Wonderland", "Death Billiards", "Death Note", "Dengeki Daisy", "Devil May Cry", "Devilman", "Diamond no Ace", "Domestic na Kanojo", "Dorohedoro", "Dororo to Hyakkimaru", "Downloader", "Dr Stone", "Dragon Ball", "Dragon Ball Z", "Dragon Ball Z Movie 07", "Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka", "Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka Gaiden", "Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka IV", "Durarara", "Echo", "Eizouken ni wa Te wo Dasu na", "Elfen Lied", "Enen no Shouboutai", "Ergo Proxy", "Eromangasensei", "Evangelion Movie 3", "Eyeshield 21", "FLCL", "Fairy Tail", "FateApocrypha", "FateExtra", "FateZero", "FateZero Remix", "Fatekaleid liner PrismaIllya", "Fatestay night", "Fatestay night Movie", "Final Fantasy VII", "Fire Punch", "Free", "Fruits Basket", "Fugou Keiji", "Full Metal Panic", "Fullmetal Alchemist", "Fumetsu no Anata e", "Fuufu Ijou Koibito Miman", "Gabriel DropOut", "Gangsta", "Gankutsuou", "Gantz", "Gate", "Gekkan Shoujo Nozakikun", "Ginga Eiyuu Densetsu", "Gintama", "Gintama Movie 1", "Given", "Goblin Slayer", "Gochuumon wa Usagi desu ka", "Gokushufudou", "Golden Boy", "Golden Kamuy", "Golden Time", "Gosick", "Grand Blue", "Grappler Baki TV", "Great Pretender", "Great Teacher Onizuka", "Grisaia no Kajitsu", "Guilty Crown", "Gunnm", "Gyakkyou Burai Kaiji", "Hachimitsu to Clover", "Haibane Renmei", "Haikyuu", "Haikyuu Karasuno Koukou vs Shiratorizawa Gakuen Koukou", "Haikyuu Lev Genzan", "Haikyuu Quest Picture Drama", "Haikyuu Riku vs Kuu", "Haikyuu Second Season", "Haikyuu To the Top", "Haiyoru Nyaruani", "Hajime no Ippo", "Happy Sugar Life", "Hataraku Maousama", "Hayate no Gotoku", "Hellsing", "Hellsing Ultimate", "Hentai Ouji to Warawanai Neko", "Hibike Euphonium", "Hibike Euphonium 2", "Hige wo Soru Soshite Joshikousei wo Hirou", "High School DxD", "Highschool of the Dead", "Higurashi no Naku Koro ni", "Himouto Umaruchan", "Hinamatsuri TV", "Hokuto no Ken", "Horisan to Miyamurakun", "Hotarubi no Mori e", "Houseki no Kuni PV", "Howl no Ugoku Shiro", "Hunter x Hunter", "Hunter x Hunter 2011", "Hunter x Hunter Movie 2", "Hyouka", "IS", "Ijiranaide Nagatorosan", "Imouto sae Ireba Ii", "Initial D Fourth Stage", "Inu x Boku SS", "InuYasha", "InuYasha Movie 3", "Itai no wa Iya nanode Bou ...

# %%
from torchvision.models import ResNet18_Weights

# %%
model = models.resnet18(weights=ResNet18_Weights.DEFAULT)  # Use ResNet18 pretrained on ImageNet
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, len(train_dataset.classes))  # Change output layer
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
from timeit import default_timer as timer
from tqdm import tqdm

# %%
import os

# Create folder for checkpoints if it doesn't exist
os.makedirs("/content/checkpoints2", exist_ok=True)

# %%
start_time = timer()
# --- Training loop skeleton ---
num_epochs = 20
for epoch in tqdm(range(num_epochs)):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")

    end_time = timer()
    elapsed_time = end_time - start_time
    print(f"Elapsed time: {elapsed_time:.2f} seconds")

    # --- Save checkpoint after each epoch ---
    torch.save(model.state_dict(), f"/content/checkpoints2/resnet18_epoch{epoch+1}.pth")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#   5%|▌         | 1/20 [03:52<1:13:44, 232.87s/it]
# Epoch [1/20], Loss: 5.7532
# Elapsed time: 232.78 seconds
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  10%|█         | 2/20 [07:44<1:09:37, 232.10s/it]
# Epoch [2/20], Loss: 4.6326
# Elapsed time: 464.29 seconds
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  15%|█▌        | 3/20 [11:34<1:05:32, 231.35s/it]
# Epoch [3/20], Loss: 3.8203
# Elapsed time: 694.79 seconds
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  20%|██        | 4/20 [15:24<1:01:30, 230.68s/it]
# Epoch [4/20], Loss: 3.1026
# Elapsed time: 924.46 seconds

# %%
# --- Save final model ---
torch.save(model.state_dict(), "/content/resnet18_final2.pth")
print("Training complete.")

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(test_loader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)

        # Get file paths for the current batch
        start_idx = batch_idx * test_loader.batch_size
        end_idx = start_idx + images.size(0)
        paths = [test_loader.dataset.imgs[i][0] for i in range(start_idx, end_idx)]

        for path, pred, label in zip(paths, preds, labels):
            pred_name = test_loader.dataset.classes[pred.item()]
            true_name = test_loader.dataset.classes[label.item()]

        # Update counters for accuracy
        correct += (preds == labels).sum().item()
        total += labels.size(0)

accuracy = correct / total
print(f"Test Accuracy: {accuracy*100:.2f}%")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import files

torch.save(model.state_dict(), 'resnet18_final1.pth')

# %%
## I forgot to make built in list to track the loss, instead I just printed it at every epoch, I am going to use those losses to visualize the general loss during the training.
